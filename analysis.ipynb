# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\axel_\Documents\conda\libertadores\matchStats\csv\fotmob_match_stats.csv')
df.tail()
# Out:
#     matchId  matchRound               homeTeamName  homeTeamid  \
# 43  5261468           3  Universitario de Deportes        4409
# 44  5261478           3                    Bolivar        5983
# 45  5261479           3    Independiente Rivadavia      161729
# 46  5261490           3                Corinthians        9808
# 47  5261458           3     Independiente Medellin        2528
#
#              awayTeamName  awayTeamid  home_goals  away_goals  \
# 43               Nacional        8304           4           2
# 44             Fluminense        9863           2           0
# 45    Deportivo La Guaira      176496           4           1
# 46  Club Atletico Penarol        8450           2           0
# 47               Cusco FC      305171           1           0
#
#     ball_possession_home  ball_possession_away  ...  ground_duels_won_home  \
# 43                    56                    44  ...               34 (52%)
# ...
